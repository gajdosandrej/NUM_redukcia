# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# _[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,_ <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
#
# **_Tento materiál vznikol za podpory grantu VVGS-2022-2412._**
#
# ***
#
# **<font size=6 color=gold> NUM: Téma 3 - Numerické derivovanie: úlohy </font>**

# %%
# nacitanie potrebnych balikov v Python-e 
import math 
import numpy as np 
import sympy as sym 
import scipy as sci 
from decimal import Decimal
from matplotlib import pyplot as plt

# %% [markdown]
# ---
#
# **$\clubsuit$ 1. Uvažujte funkciu $f(x)=\sin(x)(1-x)$.**
#
# **a) Nájdite $f'(x)$ "ručne" a overte napr. pomocou balíla *SymPy*.**
#
# **b) Využite a) k overeniu, že $f'(1)=-\sin(1)\approx-0.8414709848$.**
#
# **c) Pre aproximáciu derivácie zadanej funkcie v bode $x_0=1$ využite aproximačnú formulu prvého rádu, t. j.**
#
# $$f'(1)\approx\dfrac{f(1+h)-f(1)}{h}.$$
#
# **Vyplňte nasledúcu tabuľku (aproximácie derivácie i relatívnu chybu aproximácie) a sledujte, ako sa správa chyba aproximácie so zmenšujúcim sa $h$.**
#
# ![t5.PNG](attachment:t5.PNG)
#
# **d) Vytvorte podobné tabuľky pre $h=3^{-1},3^{-2},3^{-3}\ldots$; $h=5^{-1},5^{-2},5^{-3}\ldots$; $h=10^{-1},10^{-2},10^{-3}\ldots$; $h=\pi^{-1},\pi^{-2},\pi^{-3}\ldots$ . Odpozorovali ste niečo zaujímavé?**
#
# **e) Ak vypočítate numerickú deriváciu pomocou doprednej diferencie a následne vypočítate relatívnu chybu s pevnou hodnotou $h$, čo potom očakávate, že sa stane s absolútnou chybou, ak vydelíte hodnotu $h$ nejakou kladnou konštantou $M$ ? Vyskúšajte si niekoľko experimentov v Python-e!**
#
# **f) Ako súvisí Vaša odpoveď z e) s rádom aproximácie použitej metódy?**

# %%
# pomocny (neuplny kod), ktory mozete vyuzit pri rieseni ulohy 
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: np.sin(x) * (1-x) # co robi tento riadok kodu?
exact = -np.sin(1) # co robi tento riadok kodu?
H = 2.0**(-np.arange(1,10)) # co robi tento riadok kodu?
RelPctError = [] # zacnite s prazdnym zoznamom chyb
for h in H: 
    approx = # dokoncite tento riadok kodu 
    RelPctError.append( np.abs( (approx - exact)/exact ) * 100 )
    print("h=",h,"\t Relatívna chyba (%) =", RelPctError[-1]) 
plt.loglog(H,RelPctError,'b-*') # preco vykreslujeme loglog graf?
plt.grid()
plt.show()

# %% [markdown]
# **g) Pre úplnosť znázornite graficky aj absolútne chyby aproximácií derivácii vo vyššie uvedených scenároch - c) a d).**

# %% [markdown]
# **2. Predpokladajte, že $f(x)$ je nejaká diferencovateľná funkcia, a že jej približné derivácie $f'(x_0)$ sú počítané pomocou doprednej diferenčnej formuly, tzn.**
#
# $$f'(x_0)\approx\dfrac{f(x_0+h)-f(x_0)}{h}.$$
#
# Na základe poznatkov získaných z experimentov v 1. úlohe vyplňte nasledujúcu tabuľku
#
# ![t6.PNG](attachment:t6.PNG)
#
# a vysvetlite, čo znamená veta: Aproximácia $f'(x_0)\approx\dfrac{f(x_0+h)-f(x_0)}{h}$ (prvej) derivácie, je prvého rádu.

# %% [markdown]
# ---
#
# **3. Naprogramujte v Python-e funkciu, ktorá dostane na vstupe matematickú funkciu, krajné body intervalu, počet podintervalov (do ktorých sa rozdelí zadaný interval) a vráti derivácie vypočítané aproximáciou prvého rádu, pričom derivácie budú vypočítané vo všetkých bodoch zadaného intervalu, okrem pravého krajného bodu. Tak napr., na vstupe bude funkcia $f(x)=\sin(x)$, interval $\left[0,2\pi\right]$ a nech je tento interval rozdelený na 100 podintervalov (rovnakej dĺžky). Na výstupe by mala Python-ovska funkcia vrátiť hodnoty derivácií $f'(x)$ vo všetkých 100 bodoch, s výnimkou posledného, t. j. okrem derivácie v bode $x=\pi$ (pravý krajný bod zadaného intervalu).**
#
# **a) Zamyslite sa najprv, prečo nemožno rátať deriváciu v poslednom (pravom krajnom) bode intervalu?**
#
# **b) Ďalej vyplňte medzery v čiastočne vyplnenom kóde nižšie. Každý riadok musí mať komentár, ktorý presne vysvetľuje, čo daný riadok robí.**

# %%
import numpy as np
import matplotlib.pyplot as plt
def FirstDeriv(f,a,b,N):
    x = np.linspace(a,b,N+1) # What does this line of code do?
    # What's up with the N+1 in the previous line?
    h = x[1] - x[0] # What does this line of code do?
    df = [] # What does this line of code do?
    for j in np.arange(len(x)-1): # What does this line of code do?
        # What's up with the -1 in the definition of the loop?
        #
        # Now we want to build the approximation
        # (f(x+h) - f(x)) / h.
        # Obviously "x+h" is just the next item in the list of
        # x values so when we do f(x+h) mathematically, we should
        # write f( x[j+1] ) in Python (explain this).
        # Fill in the question marks below
df.append( (f( ??? ) - f( ??? )) / h )
return df

# %% [markdown]
# **c) Pokúste sa vylepšiť (zefektívniť) predchádzajúcu implementáciu funkcie `FirstDeriv(f,a,b,N)` využitím polí z balíka *NumPy*. Miesto prechádzania `for` cyklom cez všetky prvky v zozname, je možné aplikovať operácie s poliami ako napr. sčítať/odčítať/vynásobiť dve polia (po zložkách), prípadne vynásobiť pole konštantou resp. skalárom (t. j. vynásobiť každú jeho zložku danou konštantou) či pripočítať konštantu resp. skalár ku všetkým prvkom poľa naraz atď. Stačí len vhodne doplniť jeden riadok v nasledujúcom predpripravenom kóde.**

# %%
def FirstDeriv(f,a,b,N):
    x = np.linspace(a,b,N+1)
    h = x[1] - x[0]
    df = # your line of code goes here?
    return df

# %% [markdown]
# **d) Teraz chceme použiť túto naprogramovanú funkciu na vytvorenie aproximácie prvého rádu prvej derivácie pre nejakú funkciu. Vezmime funkciu $f(x) = \sin(x)$ na intervale $[0,2\pi]$ so 100 podintervalmi (keďže vieme, aké by malo byť riešenie). Doplňte nižšie uvedený kód, aby ste zavolali Vašu funkciu `FirstDeriv()` a vykreslili $f(x)$, $f'(x)$ a tiež aproximáciu $f'(x)$.**

# %%
f = lambda x: np.sin(x)
exact_df = lambda x: np.cos(x)
a = ???
b = ???
N = 100 # What is this?
x = np.linspace(a,b,N+1)
# What does the prevoius line do?
# What's up with the N+1?
df = FirstDeriv(f,a,b,N) # What does this line do?
# In the next line we plot three curves:
# 1) the function f(x) = sin(x)
# 2) the function f'(x) = cos(x) 
# 3) the approximation of f'(x)
# However, we do something funny with the x in the last plot. Why?
plt.plot(x,f(x),'b',x,exact_df(x),'r--',x[0:-1], df, 'k-.')
plt.grid()
plt.legend(['f(x) = sin(x)',
            'exact first deriv',
            'approx first deriv'])
plt.show()

# %% [markdown]
# **e) Skompletizovaný kód otestujte niekoľkými spôsobmi:**
#
# (i) Otestujte kód na funkciách, ktorých derivácie poznáte. Uistite sa, že dostanete grafy, ktoré očakávate.
#
# (ii) Otestujte kód s veľmi veľkým počtom podintervalov, $N$ . Čo pozorujete?
#
# (iii) Otestujte kód s malým počtom podintervalov, $N$ . Čo pozorujete?

# %% [markdown]
# ---
#
# **$\clubsuit$ 4. Napíšte kód, ktorý nájde aproximácie prvého rádu pre (prvé) derivácie funkcie $f(x)=\sin(x)-x\sin(x)$ na intervale $x\in(0,15)$. Váš kód by mal vykresliť vedľa seba dva grafy:**
#
# * **Graf na ľavej strane by mal zobrazovať funkciu modrou farbou a približnú prvú deriváciu ako červenú prerušovanú krivku. Vzorový kód pre tento problém je uvedený nižšie.**

# %%
import matplotlib.pyplot as plt
import numpy as np
f = lambda x: np.sin(x) - x*np.sin(x)
a = 0
b = 15
N = # make this an appropriately sized number of subintervals
x = np.linspace(a,b,N+1) # what does this line do?
y = f(x) # what does this line do?
df = FirstDerivFirstOrder(f,a,b,N) # what does this line do?
fig, ax = plt.subplots(1,2) # what does this line do?
ax[0].plot(x,y,'b',x[0:-1],df,'r--') # what does this line do?
ax[0].grid()

# %% [markdown]
# * **Graf vpravo by mal ukazovať absolútnu chybu medzi presnou deriváciou a numerickou deriváciou. Pre tento graf by ste mali použiť logaritmickú mierku na osi $y$.**

# %%
exact = lambda x: # write a function for the exact derivative
# There is a lot going on the next line of code ... explain it.
ax[1].semilogy(x[0:-1],abs(exact(x[0:-1]) - df))
ax[1].grid()

# %% [markdown]
# * **Experimentujte s počtom podintervalov, $N$ a ilustrujte fakt, že sa jedná o použitie metódy prvého rádu pre aproximáciu (prvej) derivácie.**

# %% [markdown]
# ---
#
# **5. Vezmite opäť funkciu $f(x)=\sin(x)(1-x)$ ale tentokrát pre aproximáciu jej prvej derivácie uvažujte vzťah**
#
# $$f'(1)\approx\dfrac{f(1+h)-f(1-h)}{2h}$$
#
# **a vyriešte 1., 3., 4. úlohu resp. zodpovedajte otázky v nich s týmto zadaním.**

# %% [markdown]
# ---
#
# **6. Predpokladajte, že $f(x)$ je nejaká diferencovateľná funkcia, a že jej približné derivácie $f'(x_0)$ sú počítané pomocou centrálnej diferenčnej formuly, tzn.**
#
# $$f'(x_0)\approx\dfrac{f(x_0+h)-f(x_0-h)}{2h}.$$
#
# **Na základe poznatkov získaných z experimentov v 5. úlohe vyplňte nasledujúcu tabuľku**
#
# ![t7.PNG](attachment:t7.PNG)
#
# **a vysvetlite, čo znamená veta: Aproximácia $f'(x_0)\approx\dfrac{f(x_0+h)-f(x_0-h)}{2h}$ (prvej) derivácie, je druhého rádu.**

# %% [markdown]
# ---
#
# **$\clubsuit$ 7. Zvoľte si konkrétnu funkciu $f$ podľa vlastného uváženia a tiež vhodný bod $x_0$. Následne vypočítajte numerické derivácie (podľa vzťahov uvedených nižšie), absolútne i relatívne chyby týchto aproximácií a vizualizujte ich do jedného grafu. Vezmite napr. $h=10^{-1},10^{-2},10^{-3}\ldots10^{-10}$, prípadne zvážte vhodnejší rozsah pre $h$ a tiež možnosť využitia logaritmickej škály. Ilustrujte vizuálne fakt, že ide o metódy rôznych rádov (tzn. rôznej presnosti).**
#
# ![Taylor2.PNG](attachment:Taylor2.PNG)

# %% [markdown]
# ---
#
# **8. Zopakujte 5. úlohu ale s centrálnym diferenčným vzorcom pre druhú deriváciu, t. j.**
#
# $$f''(x_0)\approx\dfrac{f(x_0+h)-2f(x_0)+f(x_0-h)}{h^2}.$$

# %% [markdown]
# ---
#
# **9. Predpokladajte, že $f(x)$ je nejaká dvakrát diferencovateľná funkcia, a že jej približné druhé derivácie $f''(x_0)$ sú počítané pomocou centrálnej diferenčnej formuly, tzn.**
#
# $$f''(x_0)\approx\dfrac{f(x_0+h)-2f(x_0)+f(x_0-h)}{h^2}.$$
#
# **Na základe poznatkov získaných z experimentov v 8. úlohe vyplňte nasledujúcu tabuľku**
#
# ![t8.PNG](attachment:t8.PNG)
#
# **a vysvetlite, čo znamená veta: Aproximácia $f''(x_0)\approx\dfrac{f(x_0+h)-2f(x_0)+f(x_0-h)}{h^2}$ (druhej) derivácie, je druhého rádu.**

# %% [markdown]
# ---
#
# **10. Nech $f(x)$ je dvakrát diferencovateľná funkcia. Zaujíma nás prvá a druhá derivácia funkcie $f$ v bode $x_0=1$. (V každej z nasledujúcich otázok môžete predpokladať, že funkcia $f$ je iná, no v skutočnosti to nie je podstatné, ako presne vyzerá funkcia $f$.).**
#
# a) Johnny použil numerické derivovanie pre určenie prvej derivácie s $h=0.1$ aby približne vyčíslil $f'(1.74)$ a zistil relatívnu chybu aproximácie $3.28\%$. Potom vzal $h=0.01$ a zistil relatívnu chybu $0.328\%$. Aký bol rád chyby v použitom numerickom derivovaní? Na základe čoho to viete posúdiť?
#
# b) Betty použila numerické derivovanie pre určenie prvej derivácie s $h=0.2$ aby približne určila $f'(1.74)$ a zistila relatívnu chybu aproximácie $4.32\%$. Potom vzala $h=0.1$ a zistila relatívnu chybu $1.08\%$. Ktorý prístup pre numerické derivovanie pravdepodobne použila?
#
# c) Shelby urobila nasledovný výpočet
#
# $$f'(1.74)\approx\dfrac{f(1.78)-f(1.74)}{0.04}$$
#
# a zistila relatívnu chybu $2.93\%$. Ak by teraz vypočítala
#
# $$f'(1.74)\approx\dfrac{f(1.75)-f(1.74)}{0.01},$$
#
# aká by bola nová relatívna chyba aproximácie?
#
# d) Harry chce určiť $f''(1,74)$ s relatívnou chybou menšou ako $1\%$ pomocou centrálnej diferenčnej formuly. Vyskúšal $h=0.25$ a dostal relatívnu chybu $3.71\%$. Aké ďalšie $h$ by mal teda vyskúšať, aby relatívna chyba bola menej ako $1\%$ (ale blízko k $1\%$) ?

# %% [markdown]
# ---
#
# **$\clubsuit$ 11. Uvažujte metódu pre aproximáciu derivácie takú, ktorej zaokrúhľovacia chyba je $\mathcal{O}\left(\varepsilon/h\right)$ a diskretizačná chyba je $\mathcal{O}\left(h^n\right)$. Aplikovaním postupu pre ohraničenie chyby, ktorý bol ilustrovaný v učebnom texte pri odvodení $(8)$, ukážte, že optimálne $h$ je $\mathcal{O}\left(\varepsilon^{1/(n+1)}\right)$ a hranica pre minimálnu dosiahnuteľnú chybu je $\mathcal{O}\left(\varepsilon^{n/(n+1)}\right)$.**

# %% [markdown]
# ---
#
# **$\clubsuit$ 12. Uvažujte nasledujúcu formulu pre výpočet derivácie**
#
# ![finiteDiffForm1.PNG](attachment:finiteDiffForm1.PNG)
#
# **a) Analogicky ako v $(8)$ v učebnom texte odvoďte hranicu pre chybu (zaokrúhľovaciu (*round-off*) aj diskretizačnú (*truncation*)).**
#
# **b) Určte optimálne $h$ a minimálnu dosiahnuteľnú hranicu pre chybu.**
#
# **c) S využitím uvedeného vzorca zostrojte podobnú tabuľku ako v Príklade 2 v učebnom texte.**
#
# **d) Porovnajte výsledky v tabuľke s optimálnym $h$ a s minimálnou dosiahnuteľnou chybou, ktoré ste zistili pred tým (v časti b) ).**

# %% [markdown]
# ---
#
# **13. Zopakujte Úlohu 3 ale s týmto vzorcom:**
#
# ![finiteDiffForm2.PNG](attachment:finiteDiffForm2.PNG)

# %% [markdown]
# ---
#
# **14. Predpokladajte, že $f\in C^{3}\langle a,b \rangle$ a $x_0, x_0+h, x_0+2h \in \langle a,b \rangle.$ Dokážte, že existujú konštanty $c_1$, $c_2$ také, ktoré spĺňajú**
#
# ![u1.PNG](attachment:u1.PNG)
#
# kde $c>0$ je konštanta nezávisiaca od $h$.

# %% [markdown]
# ---
#
# **15. Nech $f\in C^{\infty}(-\infty,\infty)$ a nech je dané $x_0\in\mathbb{R}$.**
#
# **a) Dokážte, že $C_h=\dfrac{f(x_0+h)-f(x_0-h)}{2h}=f'(x_0)+\displaystyle\sum\limits_{i=1}^{\infty}c_ih^{2i}$, pričom konštanty  $c_i$ pre $i=1,2,3,\ldots$ nezávisia od $h$.**
#
# **b) Predpokladajte, že $C_h$, $C_{\frac{h}{2}}$ boli vypočítané. Nájdite konštanty $\alpha_1$, $\alpha_2$ také, aby platilo $\alpha_1C_h+\alpha_2C_{\frac{h}{2}}=f'(x_0)+\mathcal{O}\left(h^4\right)$.**

# %% [markdown]
# ---
#
# **$\clubsuit$ 16. Vytvorte procedúru, ktorá vypočíta numerickú deriváciu funkcie v bode pomocou vzťahu $f'(x)\approx\dfrac{f(x+h)-f(x-h)}{2h}$ a Richardsonovej extrapolácie. Na testovanie procedúr použite napr. derivácie týchto funkcií v príslušných bodoch:**
#
# * $f(x)=\cos(x),\,x=0$;
#
# * $f(x)=\mathrm{arctan}(x),\,x=1$;
#
# * $f(x)=|x|,\,x=0$.
#
# **Urobte numerické porovnanie (z hľadiska presnosti aj času) oboch implementácií.**

# %% [markdown]
# ---
#
# **17. Nájdite chybové členy pre nasledujúce formuly:**
#
# **a) $f'(x)\approx\dfrac{f(x+3h)-f(x-h)}{4h}$;**
#
# **b) $f'(0)\approx\dfrac{f(2h)-f(0)}{2h}$.**

# %% [markdown]
# ---
#
# **18. Čo je v uvedenom postupe nesprávne?**
#
# Podľa Taylorovej vety máme
#
# ![Taylor3.PNG](attachment:Taylor3.PNG)
#
# Následným sčítaním dostaneme presný výraz pre $f''(x):$
#
# ![Taylor4.PNG](attachment:Taylor4.PNG)

# %% [markdown]
# ---
#
# **19. Odvoďte nasledovné formuly vrátane chybových členov (ich rády):**
#
# **a) $f'(x)\approx\dfrac{f(x+2h)-f(x-2h)}{4h}$;**
#
# **$\clubsuit$ b) $f''(x)\approx\dfrac{f(x+2h)-2f(x)+f(x-2h)}{4h^2}$;**
#
# **c) $f'''(x)\approx\dfrac{f(x+2h)-2f(x+h)+2f(x-h)-f(x-2h)}{2h^3}$;**
#
# **d) $f^{(4)}(x)\approx\dfrac{f(x+2h)-4f(x+h)+6f(x)-4f(x-h)+f(x-2h)}{h^4}$.**
#
# **Ktorá formula je najpresnejšia?**
#
# Nápoveda: V prípadoch c), d)  uvažujte Taylorov rad pre $D(h)\equiv f(x+h)-f(x-h)$ a $S(h)\equiv f(x+h)+f(x-h)$.

# %% [markdown]
# ---
#
# **20. Ako dobrá je nižšie uvedená formula pre aproximáciu $f'(x)+f''(x)$ ?**
#
# $$\left(\dfrac{2+h}{2h^2}\right)f(x+h)-\left(\dfrac{2}{h^2}\right)f(x)+\left(\dfrac{2-h}{2h^2}\right)f(x-h)$$
#
# Odvoďte tento vzorec spolu s jeho chybou aproximácie.

# %% [markdown]
# ---
#
# **21. S využitím dátovej tabuľky uvedenej nižšie určte $f'(2.36)$, $f''(2.36)$ pomocou metód numerického derivovania, ktoré sú $\mathcal{O}\left(h^2\right)$.**
#
# ![t10.PNG](attachment:t10.PNG)

# %% [markdown]
# ---
#
# **$\clubsuit$ 22. Nové palivo pre rekreačné lode, ktoré sa vyvíja na miestnej univerzite, testoval tím inžinierov v oblasti rybníka. Ich záujmom je zdokumentovať vplyv paliva na životné prostredie – ako rýchlo sa škvrna šíri? Nasledujúca tabuľka ukazuje kamerový záznam polomeru vlny generovanej kvapkou paliva, ktorá spadla do jazierka. S využitím dátovej tabuľky uvedenej na konci určte:**
#
# **a) Intenzitu (resp. okamžitú rýchlosť) s akou sa polomer kvapky menil v čase $t=2$.**
#
# **b) Intenzitu (resp. okamžitú rýchlosť) s akou sa plocha kontaminantu šírila v jazierku v čase $t=2$.**
#
# ![t11.PNG](attachment:t11.PNG)
#
# **Na vyriešenie úlohy použite Lagrangeov interpolačný polynóm druhého stupňa.**

# %% [markdown]
# **$\clubsuit$ 23. Nasledujúca tabuľka reprezentuje vývoj populácie - počet ľudí $n(t)$ v čase $t$, pričom intenzita pôrodnosti je konštantná ($b=2$) a intenzita úmrtnosti je daná vzťahom $d(t)=0.01n(t)$:**
#
# ![t12.PNG](attachment:t12.PNG)
#
# **Využite tieto dáta pre aproximáciu intenzity (okamžitej rýchlosti) zmeny populácie. Následne porovnajte získané výsledky so skutočnou (presnou) intenzitou $n'(t)=2n(t)-0.01n^2(t)$.**

# %% [markdown]
# ---
#
# **24. Pre funkciu $f(x)=\sin\left(x^2\right)+\dfrac{\mathrm{arctg}(x)}{1+x^4}$ vypočítajte približne jej prvú deriváciu na intervale $\langle 0,2 \rangle$ pomocou vzorca $f'(x)\approx\dfrac{f(x+h)-f(x-h)}{2h}$ s krokom $h=0.25$ aj $h=0.1$. Výsledky porovnajte s hodnotami presne vypočítanej derivácie.**

# %% [markdown]
# ---
#
# **$\clubsuit$ 25. Pre funkciu $f(x)=\sin\left(x^2\right)+\mathrm{arctg}(x)$ vypočítajte približne jej druhú deriváciu na intervale $\langle 0,2 \rangle$ pomocou vzorca $f''(x)\approx\dfrac{f(x+h)-2f(x)+f(x-h)}{h^2}$ s krokom $h=0.25$ aj $h=0.1$. Výsledky porovnajte s hodnotami presne vypočítanej derivácie.**
