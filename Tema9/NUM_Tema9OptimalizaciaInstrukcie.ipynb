# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# _[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,_ <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
#
# **_Tento materiál vznikol za podpory grantu VVGS-2022-2412._**
#
# ***
#
# **<font size=6 color=gold> NUM: Téma 9 - Optimalizácia: študijné inštrukcie </font>**

# %% [markdown]
# ***
# <a id=suhrn></a>
# # <font color=brown> Motivácia </font>

# %% [markdown]
# Objav **dvojitej špirálovej štruktúry** DNA v roku 1953 viedol o polstoročie neskôr k takmer úplnému **sekvenovaniu ľudského genómu**. Sekvencia v sebe nesie zakódované informácie o skladaní reťazcov aminokyselín do jednotlivých proteínov, ktoré vykonávajú prejavy života. Tieto informácie potrebujú preklad (dekódovanie), aby ich bolo možné nasmerovať k podrobnému porozumeniu fyziologickej funkcie. Rad potenciálnych aplikácií vrátane **génovej terapie i návrhu liečiv môže podporovať** včasnú prevenciu, diagnostiku a liečenie choroby. Skladanie aminokyselín do funkčných proteínov zásadne závisí od van der Waalsových síl, mikroskopickej príťažlivosti a odporu medzi neviazanými atómami. Pri štúdiu modelov atómových klastrov, v ktorých sú tieto sily modelované potenciálom Lennard-Jones, sú kľúčové konfigurácie s minimálnou energiou, preto na scénu prichádza **optimalizácia** a stáva sa potrebnou súčasťou naznačeného výskumu ...
#
# ![dnastructure.png](attachment:dnastructure.png)

# %% [markdown]
# Ďalšia zaujímavá, praktická úloha, kde **optimalizácia v kombinácii so strojovým učením** uľahčuje život resp. zefektívňuje procesy je nasledovná: Predstavte si veľkú databázu (rádovo v stotisícoch) textov v elektronickej podobe (básne, poviedky, odborné texty atď.) a tieto texty je potrebné automatizovaným spôsobom spoľahlivo roztriediť do kategórií (napr. podľa žánrov) tak, aby sa to nemuselo realizovať "ručne" resp. aby to reálne nemusel prechádzať a triediť človek.
#
# ![rsz_1text_classification_machine_learning_nlp.png](attachment:rsz_1text_classification_machine_learning_nlp.png)

# %% [markdown]
# **Rozpoznanie obrazu** (ang. _image recognition_) je schopnosť identifikovať napríklad objekty, miesta, ľudí, text alebo činnosť na obrázku. Rozpoznanie obrazu je široko používané v strojovo orientovaných vizuálnych úlohách, ako je napríklad označovanie obsahu obrázkov tagmi, vyhľadávanie obrázkov na základe obsahu, navigovanie robotov a riadenie autonómnych áut. Algoritmy na rozpoznávanie obrázkov sú väčšinou založené na **hlbokom strojovom učení** a najlepšie výsledky dosahujú **konvolučné neurónové siete**. Práve učiaci resp. trénovací proces neurónových sietí sa nezaobíde bez **efektívnej numerickej optimalizácie**.
#
# ![rsz_object-detection-800x400-1.jpg](attachment:rsz_object-detection-800x400-1.jpg)
#
# V prípade **minimalizácie funkcie jednej reálnej premennej** predstavíme **metódy intervalovej redukcie** a to konkrétne **modifikáciu metódy polenia intervalov, metódu zlatého rezu. Z trochu iného súdka budú **metóda kvadratickej (parabolickej) interpolácie** i **Newtonova metóda**. Pokiaľ ide o **hľadanie minima funkcie viacerých premenných**, tak z kategórie **komparatívnych metód** bude prezentovaná **Nelderova-Meadova metóda (resp. metóda simplexov)** a spomedzi **gradientných metód** sa pozrieme na **metódu najväčšieho spádu, Newtonovu metódu** a spomenieme tiež niektoré **kvázi-Newtonovske metódy**. Objasníme súvis niektorých uvedených metód s riešením sústav (ne)lineárnych rovníc.

# %% [markdown]
# ***
# <a id=ciele></a>
# # <font color=brown> Učebné ciele</font>

# %% [markdown]
# ### Základné
#
#
# * Mať prehľad o základných typoch optimalizačných úloh.
#
#
# * Rozumieť princípom vybraných metód pre nepodmienenú minimalizáciu funkcie jednej reálnej premennej: modifikovaná metóda bisekcie; metóda zlatého rezu; metóda kvadratickej (parabolickej) interpolácie.
#
#
# * S využitím príslušných výpočtových balíkov vedieť aplikovať vybrané metódy pre nepodmienenú minimalizáciu funkcií jednej reálnej premennej na riešenie konkrétnych úloh.
#
#
# * Rozumieť princípom vybraných metód pre nepodmienenú minimalizáciu funkcie viacerých reálnych premenných: Nelderova-Meadova metóda (metóda simplexov); gradientné metódy - metóda najväčšieho spádu, metóda združených gradientov, Newtonova metóda; kvázi-Newtonovske metódy - DFP a BFGS metódy.
#
#
# * S využitím príslušných výpočtových balíkov vedieť aplikovať vybrané metódy pre nepodmienenú minimalizáciu funkcií viacerých reálnych premenných na riešenie konkrétnych úloh.

# %% [markdown]
# ### Pokročilé
#
#
# * Vedieť implementovať v Python-e a vzájomne porovnať (z hľadiska presnosti a rýchlosti konvergencie) vybrané metódy pre nepodmienenú minimalizáciu funkcií jednej reálnej premennej.
#
#
# * Vedieť implementovať v Python-e a vzájomne porovnať (z hľadiska presnosti a rýchlosti konvergencie) vybrané metódy pre nepodmienenú minimalizáciu funkcií viacerých reálnych premenných.
#
#
# * Aplikovať vhodné metódy numerickej optimalizácie na riešenie jednoduchých úloh s kontextom.

# %% [markdown]
# ***
# <a id=zdroje></a>
# # <font color=brown> Zdroje k štúdiu</font>

# %% [markdown]
# ### Primárne
# (povinné)
#
#
# * Jupyter Notebook: *NUM_Tema9Optimalizacia.ipynb*

# %% [markdown]
# ### Sekundárne
# (doplňujúce)
#
#
# * Video:
#
#     * [Introduction To Optimization: Gradients, Constraints, Continuous and Discrete Variables](https://www.youtube.com/watch?v=URkmNZuFzKg&ab_channel=AlphaOpt) (3:52);
#
#     * [Golden Section Search Method](https://www.youtube.com/watch?v=hLm8xfwWYPw&ab_channel=LearnChemE) (7:42);
#
#     * [Brent's Minimization Method](https://www.youtube.com/watch?v=BQm7uTYC0sg&ab_channel=OscarVeliz) (9:00);
#
#     * [Visually Explained: Newton's Method in Optimization](https://www.youtube.com/watch?v=W7S94pq5Xuo&ab_channel=VisuallyExplained) (11:26);
#
#     * [Gradient Descent in 3 minutes](https://www.youtube.com/watch?v=qg4PchTECck&ab_channel=VisuallyExplained) (3:06);
#
#     * [Gradient descent, how neural networks learn | Chapter 2, Deep learning](https://www.youtube.com/watch?v=IHZwWFHWa-w&t=992s&ab_channel=3Blue1Brown) (21:00);
#
#     * [How Gradient Descent Works. Simple Explanation](https://www.youtube.com/watch?v=Gbz8RljxIHo&ab_channel=DataScienceGarage) (5:00);
#
#     * [Gradient Descent, Step-by-Step](https://www.youtube.com/watch?v=sDv4f4s2SB8&t=355s&ab_channel=StatQuestwithJoshStarmer) (23:53);
#
#     * [Gradient descent, Newton's method](https://www.youtube.com/watch?v=qOeU9GCnU3w&ab_channel=gr_teach) (32:21);
#
#     * [Applied Optimization - Steepest Descent](https://www.youtube.com/watch?v=BBlDWNTimoA&ab_channel=purdueMET) (29:48);
#
#     * [Steepest Descent Method (Unconstrained Optimization)](https://www.youtube.com/watch?v=sgV2xDUuzhQ&ab_channel=EngineeringEducatorAcademy) (44:20);
#
#     * [Conjugate Gradient Method](https://www.youtube.com/watch?v=h4cG8jLGmKg&ab_channel=PriyaDeo) (9:34);
#
#     * [Quasi-Newton Optimization Methods](https://www.youtube.com/watch?v=uo2z0AT_83k&ab_channel=MichaelZibulevsky) (19:16);
#
#     * [Mod-06 Lec-11 Line Search Techniques](https://www.youtube.com/watch?v=8tqaXIM6kEE&list=PL6EA0722B99332589&index=12&ab_channel=nptelhrd) (57:00);
#
#     * [Mod-06 Lec-12 Global Convergence Theorem](https://www.youtube.com/watch?v=0UIt48Dt-5c&list=PL6EA0722B99332589&index=13&ab_channel=nptelhrd) (57:36);
#
#     * [Mod-06 Lec-13 Steepest Descent Method](https://www.youtube.com/watch?v=V64HwFDLnoc&list=PL6EA0722B99332589&index=14&ab_channel=nptelhrd) (57:10);
#
#     * [Mod-06 Lec-14 Classical Newton Method](https://www.youtube.com/watch?v=QnLvBNp8gkg&list=PL6EA0722B99332589&index=15&ab_channel=nptelhrd) (57:35);
#
#     * [Mod-06 Lec-15 Trust Region and Quasi-Newton Methods](https://www.youtube.com/watch?v=Xxi8Cro-ssQ&list=PL6EA0722B99332589&index=16&ab_channel=nptelhrd) (57:02);
#
#     * [Mod-06 Lec-16 Quasi-Newton Methods - Rank One Correction, DFP Method](https://www.youtube.com/watch?v=H6CCJ5c3WQw&list=PL6EA0722B99332589&index=17&ab_channel=nptelhrd) (57:30);
#
#     * [Mod-06 Lec-18 Conjugate Directions](https://www.youtube.com/watch?v=ih6z8Gi1MlY&list=PL6EA0722B99332589&index=19&ab_channel=nptelhrd) (56:24);
#
#     * [Mod-06 Lec-19 Quasi-Newton Methods - Rank One Correction, DFP Method](https://www.youtube.com/watch?v=pjcq2y1cA-4&list=PL6EA0722B99332589&index=20&ab_channel=nptelhrd) (55:39);
#
#     * [Nelder Mead Animation](https://www.youtube.com/watch?v=HUqLxHfxWqU&ab_channel=brainbrian123) (0:20);
#
#     * [Introduction To Optimization: Gradient Free Algorithms (2/2) Simulated Annealing, Nelder-Mead](https://www.youtube.com/watch?v=NI3WllrvWoc&ab_channel=AlphaOpt) (4:13).
#
#
# * Vlastné zdroje (ak nejaké zaujímavé nájdete, nezabudnite ich zdieľať ako príspevok k danej téme v Google triede).

# %% [markdown]
# ***
# <a id=ulohy></a>
# # <font color=brown> Úlohy k učebnému textu </font>

# %% [markdown]
# 1. Ilustrujte algoritmus hľadania počiatočného intervalu obsahujúceho bod minima na vhodnom príklade v Python-e. Uvažovanú funkciu vykreslite.

# %% [markdown]
# 2. Odkrokujte v Pythone výpočet z Príkladu 1. Pre porovnanie rýchlosti konvergencie vyskúšajte aj metódu obyčajnej trisekcie a výsledok okomentujte.

# %% [markdown]
# 3. Odkrokujte v Python-e výpočet z Príkladu 2.

# %% [markdown]
# 4.  Aplikujte Nelderov-Meadov algoritmus implementovaný v Python-e (knižnica _scipy_, modul _optimize_) na nájdenie lokálnych miním funkcie $h(x)=x^2+2\sin(\pi x)$. Vizualizujte zadanú funkciu vrátane jej lokálnych miním.

# %% [markdown]
# 5. Aké **konkrétne** otázky máte k náplni študijných materiálov, ktoré by ste chceli na hodine prediskutovať?
