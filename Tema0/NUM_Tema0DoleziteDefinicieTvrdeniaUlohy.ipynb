# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# _[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,_ <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
#
# **_Tento materiál vznikol za podpory grantu VVGS-2022-2412._**
#
# ***
#
# **<font size=6 color=gold> NUM: Téma 0 - Dôležité definície a tvrdenia: úlohy</font>**

# %%
# nacitanie potrebnych balikov v Python-e 
import math 
import numpy as np 
import sympy as sym 
import scipy as sci 
from decimal import Decimal
from matplotlib import pyplot as plt

# %% [markdown]
# ---
#
# 1.  Vyriešte nasledovné:
#
#     $\clubsuit$ a) Dokážte, že pre $\forall x,y\le0$: $\left|e^x-e^y\right|\le|x-y|$ (_využite Lagrangeovu vetu o strednej hodnote_).
#
#     b) Ukážte, že pre $0\le y \le x$ a $p\ge1$ platí $py^{p-1}(x-y)\le x^p-y^p\le px^{p-1}(x-y)$.
#
#     $\clubsuit$ c) Nech $f(x)$ je spojitá funkcia na intervale $\langle a,b \rangle$ a nech $S=\displaystyle\sum\limits_{j=1}^{n}w_jf(x_j)$, pričom $x_j\in\langle a,b \rangle$, $w_j\ge0$ pre $j=1,\ldots,n$ a $\displaystyle\sum\limits_{j=1}^{n}w_j=1$. Dokážte, že $S=f(\xi)$ pre nejaké $\xi\in\langle a,b \rangle$ (_aplikujte prvú vetu o strednej hodnote_).
#
#     d) Nech $f'\in C\langle a,b \rangle$ a $f'(x)\neq0$ pre všetky $x\in(a,b)$. Vysvetlite, v koľkých bodoch môže byť funkcia nulová. Svoju odpoveď zdôvodnite.

# %% [markdown]
# ---
#
# 2. Nájdite taký polynóm $p(x)$, ktorý bude spĺňať $|\mathrm{sinc}(x)-p(x)|\le10^{-10}$ pre $x\in\langle-0.2,0.2\rangle$, pričom $\mathrm{sinc}(x)=\begin{cases}\dfrac{\sin x}{x}, \quad x\neq0 \\ 1, \qquad x=0\end{cases}$ je "sinc" funkcia, známa napr. z oblasti spracovania signálov. Dokážte, že Vami navrhnutý polynóm $p$ spĺňa požadovanú podmienku.
#
#     *Pomôcka: Aproximácie funkcie $\mathrm{sinc}(x)$ pomocou polynómov s chybovými členmi je môžné získať tak, že zapíšete Taylorove polynómy a zodpovedajúce chybové členy pre $sin(x)$ a následne ich vydelíte premennou $x$. Môže to byť jednoduchšie ako sa pokúšať derivovať samotnú funkciu $\mathrm{sinc}(x)$. Na dôkazovú časť môžete použiť napríklad vzorec pre zvyšok  Taylorovho radu alebo [test alternujúceho radu](https://tutorial.math.lamar.edu/classes/calcii/AlternatingSeries.aspx) (t.j. kritérium konvergencie radu so striedavými znamienkami) ...*

# %% [markdown]
# ---
#
# $\clubsuit$ 3. Predpokladajte, že funkcia $f$ má spojité derivácie do rádu tri (vrátane). Ukážte, že $\left|\dfrac{f(x+h)-f(x-h)}{2h}-f'(x)\right|=\mathcal{O}\left(h^2\right)$. Situáciu znázornite graficky v Python-e (_aplikujte Taylorovu vetu_).

# %% [markdown]
# ---
#
# 4. Predpokladajte, že funkcia $f$ má spojité derivácie do rádu štyri (vrátane). Ukážte, že $\left|\dfrac{f(x+h)-2f(x)+f(x-h)}{h^2}-f''(x)\right|=\mathcal{O}\left(h^2\right)$. Situáciu znázornite graficky v Python-e.

# %% [markdown]
# ---
#
# 5. Nech $x_n=e^{1/n}-1/n-1$ a $\alpha_n=1/n$. Ukážte, že $x_n=\mathcal{O}\left(\alpha_n^2\right)$. Situáciu znázornite graficky v Python-e.

# %% [markdown]
# ---
#
# $\clubsuit$ 6. Znázornite (v Python-e) a preskúmajte rýchlosť konvergencie postupnosti $\left\{x_n\right\}$, ak je dané:
#
#    a) $x_n=1+(1/2)^n$; ukážte, že táto postupnosť konverguje lineárne ale nie superlineárne;
#
#    b) $x_n=1+(1/n)^n$; ukážte, že táto postupnosť konverguje superlineárne ale nie kvadraticky;
#
#    c) $x_n=1+(1/n)^{2^n}$; ukážte, že táto postupnosť konverguje kvadraticky.

# %% [markdown]
# ---
#
# 7. Dokážte, že ak postupnosť konverguje rýchlosťou rádu $p>1$, potom konverguje i superlineárne.

# %% [markdown]
# ---
#
# $\clubsuit$ 8. Ukážte, že postupnosť $\left\{\dfrac{1}{n^n}\right\}_{n=1}^{\infty}$ konverguje superlineárne k nule, no nekonverguje k nule rýchlosťou rádu $p$, kde $p>1$.

# %% [markdown]
# ---
#
# $\clubsuit$ 9. Overte (pomôžte si experimentovaním a vizualizáciami v Python-e), či nasledujúce postupnosti konvergujú. V prípade, že konvergujú, určte rýchlosť konvergencie. Zamerajte sa na a), b), e).
#
# ![o2.PNG](attachment:o2.PNG)

# %% [markdown]
# ---
#
# $\clubsuit$ 10. Zostrojte a znázornite konvergentnú postupnosť rádu $p=3/2$. Na základe vygenerovaných dát odhadnite jej rád konvergencie $p$.

# %% [markdown]
# ---
#
# 11. Podobne ako v Príklade 11 vygenerujte i znázornite sublineárne konvergentnú postupnosť $\left\{\dfrac{1}{k}\right\}_{k=1}^{\infty}$, pričom voľte postupne $n$ z množiny $\{50,100,500,1000,5000,10000\}$. Ako sa menia odhady $q$ pre rôzne hodnoty $n$ ?

# %% [markdown]
# ---
#
# $\clubsuit$ 12. Zdôvodnite: ak $f=\mathcal{O}(g)$ a súčasne $g=\mathcal{O}(h)$, potom $f=\mathcal{O}(h)$. Uveďte príklad a znázornite.

# %% [markdown]
# ---
#
# 13. Zdôvodnite: ak $f=\mathcal{O}(g)$ a súčasne $h=\mathcal{O}(k)$, potom $fh=\mathcal{O}(gk)$. Uveďte príklad a znázornite.

# %% [markdown]
# ---
#
# $\clubsuit$ 14. Pokúste sa navrhnúť, implementovať a otestovať ďalšie spôsoby ako odhadnúť rád konvergencie $p$ postupnosti $\{x_k\}$, ak máte k dispozícii konečnú postupnosť chýb $\varepsilon=\left|x_k-x^*\right|$, pričom $\lim\limits_{k\to\infty}x_k=x^*$. Na testovanie a porovnanie pístupov môžete využiť dáta z Príkladu 11.
